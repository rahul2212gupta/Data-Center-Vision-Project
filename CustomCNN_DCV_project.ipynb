# %%
import kagglehub
omkarmanohardalvi_lungs_disease_dataset_4_types_path = kagglehub.dataset_download('omkarmanohardalvi/lungs-disease-dataset-4-types')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
# Import Libraries
import tensorflow as tf
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
# Define Paths
data_dir = '/kaggle/input/lungs-disease-dataset-4-types/Lung Disease Dataset/train'
test_dir = '/kaggle/input/lungs-disease-dataset-4-types/Lung Disease Dataset/test'

# %%
# Parameters
image_size = (224, 224)
batch_size = 32
num_classes = 5
num_folds = 5  # Number of folds for cross-validation
epochs_per_fold = 30

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data Augmentation (Advanced)
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet.preprocess_input,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
# Validation & Test - No Augmentation
val_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet.preprocess_input)

# %%
# Load Test Dataset
test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2025 images belonging to 5 classes.

# %%
# Prepare Data for K-Fold Cross-Validation
image_files = []
labels = []
for class_name in os.listdir(data_dir):
    class_dir = os.path.join(data_dir, class_name)
    if os.path.isdir(class_dir):
        for img_file in os.listdir(class_dir):
            image_files.append(os.path.join(class_dir, img_file))
            labels.append(class_name)

# %%
# Convert labels to numeric
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Create DataFrame
df = pd.DataFrame({'image_path': image_files, 'label': labels})

# %%
# Define K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Learning Rate Scheduler (Cosine Annealing)
def cosine_annealing(epoch):
    initial_lr = 1e-4  # Lower initial LR for Adam
    return initial_lr * 0.5 * (1 + math.cos(math.pi * epoch / epochs_per_fold))

# %%
# Function to Build a Custom CNN Model
def build_model():
    inputs = Input(shape=(224, 224, 3))

    x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    x = tf.keras.layers.Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from sklearn.utils.class_weight import compute_class_weight

# Perform K-Fold Cross-Validation
best_test_acc = 0
best_model_path = ""
all_histories = []
all_test_preds = np.zeros((len(test_dataset.classes), num_classes))

# Convert labels back to string class names (ensure consistency)
df['label'] = label_encoder.inverse_transform(df['label'].values)

for fold, (train_idx, val_idx) in enumerate(skf.split(df['image_path'], df['label'])):
    print(f"Training Fold {fold + 1}/{num_folds}")

    # Create train/val DataFrames
    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    # Create Generators
    train_dataset_fold = train_datagen.flow_from_dataframe(
        train_df,
        x_col="image_path",
        y_col="label",
        target_size=image_size,
        batch_size=batch_size,
        class_mode="categorical",
        shuffle=True
    )
    val_dataset_fold = val_datagen.flow_from_dataframe(
        val_df,
        x_col="image_path",
        y_col="label",
        target_size=image_size,
        batch_size=batch_size,
        class_mode="categorical",
        shuffle=False
    )

    # ---- FIXED CLASS WEIGHTS ----
    # Extract labels as strings
    y_train = train_df['label'].astype(str).values
    class_labels = np.unique(y_train)

    # Compute class weights
    class_weights_array = compute_class_weight(
        class_weight='balanced',
        classes=class_labels,
        y=y_train
    )

    # Map string labels to class indices used by the generator
    class_indices = train_dataset_fold.class_indices  # e.g., {'cat': 0, 'dog': 1}
    class_weights_dict = {
        class_indices[label]: weight
        for label, weight in zip(class_labels, class_weights_array)
        if label in class_indices
    }

    # Build Model
    model = build_model()
# Out:
# Training Fold 1/5
# Found 4843 validated image filenames belonging to 5 classes.
# Found 1211 validated image filenames belonging to 5 classes.
# Training Fold 2/5
# Found 4843 validated image filenames belonging to 5 classes.
# Found 1211 validated image filenames belonging to 5 classes.
# Training Fold 3/5
# Found 4843 validated image filenames belonging to 5 classes.
# Found 1211 validated image filenames belonging to 5 classes.
# Training Fold 4/5
# Found 4843 validated image filenames belonging to 5 classes.
# Found 1211 validated image filenames belonging to 5 classes.
# Training Fold 5/5
# Found 4844 validated image filenames belonging to 5 classes.
# Found 1210 validated image filenames belonging to 5 classes.

# %%
    # Callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
    checkpoint = ModelCheckpoint(
        filepath=f'/kaggle/working/best_model_fold_{fold + 1}.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    lr_scheduler = LearningRateScheduler(cosine_annealing)






    # Train Model
    history = model.fit(
        train_dataset_fold,
        epochs=epochs_per_fold,
        validation_data=val_dataset_fold,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr, checkpoint, lr_scheduler]
    )
    all_histories.append(history)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.2528 - loss: 11.3425
# Epoch 1: val_loss improved from inf to 1.35984, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 159s 988ms/step - accuracy: 0.2530 - loss: 11.2976 - val_accuracy: 0.3992 - val_loss: 1.3598 - learning_rate: 1.0000e-04
# Epoch 2/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.3271 - loss: 1.4626
# Epoch 2: val_loss improved from 1.35984 to 1.21513, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 133s 875ms/step - accuracy: 0.3272 - loss: 1.4624 - val_accuracy: 0.4636 - val_loss: 1.2151 - learning_rate: 9.9726e-05
# Epoch 3/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.3921 - loss: 1.3665
# Epoch 3: val_loss improved from 1.21513 to 1.09099, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 135s 888ms/step - accuracy: 0.3921 - loss: 1.3665 - val_accuracy: 0.6471 - val_loss: 1.0910 - learning_rate: 9.8907e-05
# Epoch 4/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.4008 - loss: 1.3367
# Epoch 4: val_loss improved from 1.09099 to 0.98908, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 138s 903ms/step - accuracy: 0.4009 - loss: 1.3365 - val_accuracy: 0.6339 - val_loss: 0.9891 - learning_rate: 9.7553e-05
# Epoch 5/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.4719 - loss: 1.2238
# Epoch 5: val_loss improved from 0.98908 to 0.85374, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 798ms/step - accuracy: 0.4719 - loss: 1.2237 - val_accuracy: 0.6727 - val_loss: 0.8537 - learning_rate: 9.5677e-05
# Epoch 6/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.4902 - loss: 1.1833
# Epoch 6: val_loss improved from 0.85374 to 0.75154, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 142s 799ms/step - accuracy: 0.4903 - loss: 1.1832 - val_accuracy: 0.7231 - val_loss: 0.7515 - learning_rate: 9.3301e-05
# Epoch 7/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.5516 - loss: 1.0981
# Epoch 7: val_loss improved from 0.75154 to 0.72685, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 129s 849ms/step - accuracy: 0.5516 - loss: 1.0980 - val_accuracy: 0.7240 - val_loss: 0.7268 - learning_rate: 9.0451e-05
# Epoch 8/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.5852 - loss: 1.0453
# Epoch 8: val_loss improved from 0.72685 to 0.70583, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 129s 849ms/step - accuracy: 0.5852 - loss: 1.0452 - val_accuracy: 0.7025 - val_loss: 0.7058 - learning_rate: 8.7157e-05
# Epoch 9/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.5780 - loss: 1.0152
# Epoch 9: val_loss improved from 0.70583 to 0.69427, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 128s 840ms/step - accuracy: 0.5781 - loss: 1.0153 - val_accuracy: 0.7331 - val_loss: 0.6943 - learning_rate: 8.3457e-05
# Epoch 10/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.5908 - loss: 1.0118
# Epoch 10: val_loss improved from 0.69427 to 0.66938, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 135s 887ms/step - accuracy: 0.5908 - loss: 1.0117 - val_accuracy: 0.7314 - val_loss: 0.6694 - learning_rate: 7.9389e-05
# Epoch 11/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.5865 - loss: 0.9871
# Epoch 11: val_loss improved from 0.66938 to 0.63245, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 126s 826ms/step - accuracy: 0.5866 - loss: 0.9870 - val_accuracy: 0.7554 - val_loss: 0.6324 - learning_rate: 7.5000e-05
# Epoch 12/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6196 - loss: 0.9366
# Epoch 12: val_loss improved from 0.63245 to 0.62665, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 127s 835ms/step - accuracy: 0.6196 - loss: 0.9365 - val_accuracy: 0.7545 - val_loss: 0.6267 - learning_rate: 7.0337e-05
# Epoch 13/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.6299 - loss: 0.8995
# Epoch 13: val_loss did not improve from 0.62665
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 799ms/step - accuracy: 0.6299 - loss: 0.8996 - val_accuracy: 0.6802 - val_loss: 0.7237 - learning_rate: 6.5451e-05
# Epoch 14/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.6421 - loss: 0.9188
# Epoch 14: val_loss did not improve from 0.62665
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 125s 825ms/step - accuracy: 0.6421 - loss: 0.9187 - val_accuracy: 0.7066 - val_loss: 0.6964 - learning_rate: 6.0396e-05
# Epoch 15/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.6342 - loss: 0.8996
# Epoch 15: val_loss did not improve from 0.62665
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 799ms/step - accuracy: 0.6343 - loss: 0.8995 - val_accuracy: 0.7421 - val_loss: 0.6312 - learning_rate: 1.1045e-05
# Epoch 16/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.6590 - loss: 0.8509
# Epoch 16: val_loss did not improve from 0.62665
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 797ms/step - accuracy: 0.6590 - loss: 0.8510 - val_accuracy: 0.7289 - val_loss: 0.6663 - learning_rate: 5.0000e-05
# Epoch 17/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.6373 - loss: 0.8859
# Epoch 17: val_loss did not improve from 0.62665
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 799ms/step - accuracy: 0.6373 - loss: 0.8857 - val_accuracy: 0.7421 - val_loss: 0.6612 - learning_rate: 4.4774e-05
# Epoch 18/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.6684 - loss: 0.8366
# Epoch 18: val_loss improved from 0.62665 to 0.59611, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 123s 811ms/step - accuracy: 0.6683 - loss: 0.8367 - val_accuracy: 0.7471 - val_loss: 0.5961 - learning_rate: 3.9604e-05
# Epoch 19/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.6653 - loss: 0.8271
# Epoch 19: val_loss did not improve from 0.59611
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 133s 879ms/step - accuracy: 0.6653 - loss: 0.8271 - val_accuracy: 0.7463 - val_loss: 0.5963 - learning_rate: 3.4549e-05
# Epoch 20/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.6651 - loss: 0.8114
# Epoch 20: val_loss did not improve from 0.59611
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 795ms/step - accuracy: 0.6651 - loss: 0.8114 - val_accuracy: 0.7463 - val_loss: 0.6092 - learning_rate: 2.9663e-05
# Epoch 21/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.6662 - loss: 0.8139
# Epoch 21: val_loss did not improve from 0.59611
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 120s 791ms/step - accuracy: 0.6662 - loss: 0.8137 - val_accuracy: 0.7455 - val_loss: 0.6122 - learning_rate: 5.0000e-06
# Epoch 22/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6817 - loss: 0.7951
# Epoch 22: val_loss improved from 0.59611 to 0.57961, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 127s 838ms/step - accuracy: 0.6817 - loss: 0.7951 - val_accuracy: 0.7446 - val_loss: 0.5796 - learning_rate: 2.0611e-05
# Epoch 23/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.6868 - loss: 0.7778
# Epoch 23: val_loss did not improve from 0.57961
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 794ms/step - accuracy: 0.6868 - loss: 0.7778 - val_accuracy: 0.7496 - val_loss: 0.5843 - learning_rate: 1.6543e-05
# Epoch 24/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.7006 - loss: 0.7722
# Epoch 24: val_loss did not improve from 0.57961
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 122s 801ms/step - accuracy: 0.7006 - loss: 0.7721 - val_accuracy: 0.7479 - val_loss: 0.5851 - learning_rate: 1.2843e-05
# Epoch 25/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.6870 - loss: 0.7690
# Epoch 25: val_loss improved from 0.57961 to 0.57532, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 798ms/step - accuracy: 0.6871 - loss: 0.7689 - val_accuracy: 0.7570 - val_loss: 0.5753 - learning_rate: 9.5492e-06
# Epoch 26/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.6835 - loss: 0.7588
# Epoch 26: val_loss did not improve from 0.57532
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 120s 790ms/step - accuracy: 0.6835 - loss: 0.7588 - val_accuracy: 0.7653 - val_loss: 0.5809 - learning_rate: 6.6987e-06
# Epoch 27/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.6968 - loss: 0.7424
# Epoch 27: val_loss did not improve from 0.57532
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 122s 801ms/step - accuracy: 0.6968 - loss: 0.7424 - val_accuracy: 0.7455 - val_loss: 0.6028 - learning_rate: 4.3227e-06
# Epoch 28/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.6949 - loss: 0.7725
# Epoch 28: val_loss improved from 0.57532 to 0.56113, saving model to /kaggle/working/best_model_fold_5.keras
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 797ms/step - accuracy: 0.6949 - loss: 0.7725 - val_accuracy: 0.7579 - val_loss: 0.5611 - learning_rate: 2.4472e-06
# Epoch 29/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.6925 - loss: 0.7436
# Epoch 29: val_loss did not improve from 0.56113
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 121s 797ms/step - accuracy: 0.6925 - loss: 0.7437 - val_accuracy: 0.7512 - val_loss: 0.5769 - learning_rate: 1.0926e-06
# Epoch 30/30
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.6961 - loss: 0.7696
# Epoch 30: val_loss did not improve from 0.56113
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 118s 778ms/step - accuracy: 0.6961 - loss: 0.7696 - val_accuracy: 0.7562 - val_loss: 0.5719 - learning_rate: 2.7391e-07

# %%
    # Evaluate on Test Set
    model.load_weights(f"/kaggle/working/best_model_fold_{fold + 1}.keras")
    _, test_acc = model.evaluate(test_dataset)
    if test_acc > best_test_acc:
        best_test_acc = test_acc
        best_model_path = f"/kaggle/working/best_model_fold_{fold + 1}.keras"
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 27s 426ms/step - accuracy: 0.6804 - loss: 0.6394

# %%
    # Ensemble Predictions
    fold_preds = model.predict(test_dataset)
    all_test_preds += fold_preds
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 301ms/step

# %%
# Final Test Evaluation (Using Best Model)
final_model = build_model()
final_model.load_weights(best_model_path)
final_loss, final_accuracy = final_model.evaluate(test_dataset)
print(f"\nBest Fold Model Test Accuracy: {final_accuracy:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 26 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 0.6804 - loss: 0.6394
#
# Best Fold Model Test Accuracy: 0.7709

# %%
# Ensemble Final Predictions
final_preds = np.argmax(all_test_preds / num_folds, axis=1)

# %%
# Classification Report
print("\nFinal Classification Report (Ensemble):")
print(classification_report(test_dataset.classes, final_preds, target_names=test_dataset.class_indices.keys()))
# Out:
# Final Classification Report (Ensemble):
#                       precision    recall  f1-score   support
#
#  Bacterial Pneumonia       0.64      0.49      0.56       403
# Corona Virus Disease       0.91      0.91      0.91       407
#               Normal       0.73      0.95      0.82       404
#         Tuberculosis       0.98      0.93      0.96       408
#      Viral Pneumonia       0.58      0.57      0.57       403
#
#             accuracy                           0.77      2025
#            macro avg       0.77      0.77      0.76      2025
#         weighted avg       0.77      0.77      0.77      2025

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(test_dataset.classes, final_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_dataset.class_indices.keys(), yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Test Set')
plt.show()
